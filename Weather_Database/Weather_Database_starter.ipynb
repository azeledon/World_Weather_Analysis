# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-41.09438051830647, 114.2514354797006), (87.89316873342068, 116.37873055491553), (-79.26892817846112, 134.09315149271487), (-24.769203379701636, 102.86811759990769), (-23.159426989625615, 125.47517995923141), (-59.862425389379645, -15.875114669405576), (-40.90587317896303, -17.465746312617625), (82.29802427381367, -6.3374565279892465), (-14.119256550404486, -98.4739175133455), (-53.33740979890182, -82.50432194421134), (-39.64324347137082, 91.74022947857776), (51.97162573491596, 63.592850554923416), (-31.258854813377262, 9.635868919087642), (-35.60594658734699, 79.70985198594906), (-5.437190423870405, -6.8661294703620115), (-15.754308368569724, -10.076953405266266), (-4.00660994689926, -10.396805982298673), (-46.55963256154363, 89.83983814126367), (86.60610176734366, 105.73384210711112), (38.09398542798198, -45.71831944362805), (-62.34778642663573, -143.5107938590137), (-86.50188016476775, -56.345805102203244), (56.57075685316846, -20.69301469742416), (-12.411771293155311, -128.85371936417496), (73.4587949393621, 86.38790642746108), (44.40867969826019, -148.19455065009723), (82.28301737976696, -7.464908528573432), (-80.87057659337819, -145.2488335251509), (-67.56406454048076, -47.128724364960846), (-1.871363207721771, -39.19922131435564), (76.8510332095893, -151.25046193157672), (83.4467978862491, -110.5805998026207), (22.9188507133057, 73.33668447815262), (-62.60050850831673, 123.83894156208277), (-50.10245222042188, 133.5334905757694), (-67.69280609529034, -135.0250970624032), (40.150031284004115, -107.1107812810006), (-19.61178695731246, 32.39116600687606), (26.90835815563041, 40.43268521060028), (-7.766492423299098, 69.18295285743167), (-85.45472673416009, -98.49763736488833), (52.52955050899064, -109.57853159390062), (74.79091377047206, -171.48896703901423), (37.21121766329057, -66.86099222864246), (67.87856897982243, -36.847329180992915), (71.9795802892861, 155.88526373161977), (-3.998773850326984, 97.84935540998333), (-6.911767759491639, -60.85178065501812), (-87.86739911368353, 133.26515279547874), (-0.15167478079308694, -22.971713768368176), (42.623829121808456, -14.829738342164404), (7.247152541676542, 36.22583699808706), (-17.221325307096365, -166.48597068896683), (-25.369362026742778, -33.60258358928408), (51.45168756682662, -4.247504158168823), (52.338232701847716, -61.5078302950228), (21.60702643118576, -60.08796717614001), (59.12088429041313, 140.04098317981027), (-79.62553448198561, 30.44890584132554), (-51.68192965192199, 100.96055817005401), (44.329531256438315, -47.58818619292592), (48.32075913009601, 57.65904427995258), (6.479259800694436, -5.3859156385242954), (22.297123425148172, 43.97195051791644), (64.76627260244848, 34.32250463693691), (36.23851750094116, 73.72004577445205), (-57.82533623285758, -5.890904692464318), (-35.16628966204266, -103.49020374936559), (-15.765457811431702, -77.67901711110707), (-65.89009223864812, -157.479289120597), (64.58689291268658, -117.56256995192777), (-62.1592227186006, -24.900550312542833), (-62.315994018859286, -90.58409756813548), (82.58781348981597, -118.94557348901952), (-75.47002459399158, 71.09288313909417), (80.02259741377924, -91.18059516690198), (-35.169229394331495, -31.091652104658266), (45.99622639824511, 105.65260573738112), (-18.12159004339489, 167.34228562533252), (11.130779186182764, 107.64315356683602), (69.20968558937096, 170.73734093965214), (82.70296948793711, -30.782409350357625), (-71.96176881869026, -47.08729181495795), (53.70568300359594, 35.902654530275356), (11.503515029275846, 176.29584239368785), (-20.299887195102926, -111.21785077252098), (79.61179450035482, 91.19511150624805), (-27.72732456465944, -162.51590441876775), (-17.865288693470802, -176.90664220568823), (-4.187552436365863, -44.382408279983366), (44.49325308432398, -62.12686688460259), (57.248113129443055, -167.35164835968033), (73.30257554736656, -68.93197996322598), (6.726958349427477, 31.723290115763632), (9.415277128123122, -46.05934610656087), (-37.87568694123854, -133.080391 ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | yulara
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | kushmurun
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | torbay
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | vestmannaeyjar
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | dudinka
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | itarema
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | balasinor
# City not found. Skipping...
# Processing Record 28 of Set 1 | mount gambier
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | steamboat springs
# Processing Record 31 of Set 1 | chipinge
# Processing Record 32 of Set 1 | sakakah
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | macklin
# Processing Record 35 of Set 1 | lavrentiya
# Processing Record 36 of Set 1 | nantucket
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | srednekolymsk
# Processing Record 39 of Set 1 | padang
# Processing Record 40 of Set 1 | manicore
# Processing Record 41 of Set 1 | muros
# Processing Record 42 of Set 1 | bonga
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | sao joao da barra
# Processing Record 45 of Set 1 | llanelli
# Processing Record 46 of Set 1 | havre-saint-pierre
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | solnechnyy
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | shubarshi
# Processing Record 1 of Set 2 | oume
# Processing Record 2 of Set 2 | riyadh
# Processing Record 3 of Set 2 | kem
# Processing Record 4 of Set 2 | gilgit
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | santiago
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | norman wells
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | mandalgovi
# Processing Record 13 of Set 2 | vila
# Processing Record 14 of Set 2 | phan thiet
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | bolkhov
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | neiafu
# Processing Record 21 of Set 2 | sao mateus do maranhao
# Processing Record 22 of Set 2 | antigonish
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 26 of Set 2 | cayenne
# Processing Record 27 of Set 2 | atasu
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | saldanha
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | santa cruz de la palma
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | mastic beach
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | behat
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | vila velha
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | mehamn
# Processing Record 41 of Set 2 | nikolskoye
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | orcopampa
# Processing Record 44 of Set 2 | cehegin
# Processing Record 45 of Set 2 | dunedin
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | salinas
# Processing Record 49 of Set 2 | qui nhon
# Processing Record 50 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 3 | ararat
# Processing Record 2 of Set 3 | santo antonio do ica
# Processing Record 3 of Set 3 | concarneau
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 3 | estelle
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | goundam
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | gornopravdinsk
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | guerrero negro
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | korla
# Processing Record 18 of Set 3 | rameswaram
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | samarai
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | mizan teferi
# Processing Record 23 of Set 3 | totma
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | road town
# Processing Record 26 of Set 3 | hirara
# Processing Record 27 of Set 3 | akyab
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | northam
# Processing Record 31 of Set 3 | lagoa
# Processing Record 32 of Set 3 | svetlyy
# Processing Record 33 of Set 3 | haapu
# City not found. Skipping...
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | nakanojo
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | caceres
# Processing Record 38 of Set 3 | gzhatsk
# City not found. Skipping...
# Processing Record 39 of Set 3 | saint-joseph
# Processing Record 40 of Set 3 | romanovka
# Processing Record 41 of Set 3 | aklavik
# Processing Record 42 of Set 3 | porto nacional
# Processing Record 43 of Set 3 | dickinson
# Processing Record 44 of Set 3 | saint-augustin
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | la ronge
# Processing Record 47 of Set 3 | winslow
# Processing Record 48 of Set 3 | kanniyakumari
# Processing Record 49 of Set 3 | portland
# Processing Record 50 of Set 3 | bloemfontein
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | sinnamary
# Processing Record 3 of Set 4 | esperance
# Processing Record 4 of Set 4 | dwarka
# Processing Record 5 of Set 4 | hasaki
# Processing Record 6 of Set 4 | tateyama
# Processing Record 7 of Set 4 | castro
# Processing Record 8 of Set 4 | puerto carreno
# Processing Record 9 of Set 4 | george
# Processing Record 10 of Set 4 | hopkinsville
# Processing Record 11 of Set 4 | verkhnevilyuysk
# Processing Record 12 of Set 4 | port-gentil
# Processing Record 13 of Set 4 | wahiawa
# Processing Record 14 of Set 4 | grand-santi
# Processing Record 15 of Set 4 | adrar
# Processing Record 16 of Set 4 | komsomolskiy
# Processing Record 17 of Set 4 | bicske
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 4 | dongkan
# Processing Record 21 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 4 | bengkulu
# Processing Record 23 of Set 4 | tafresh
# Processing Record 24 of Set 4 | mackay
# Processing Record 25 of Set 4 | pachino
# Processing Record 26 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 4 | cortez
# Processing Record 28 of Set 4 | fort nelson
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | isla vista
# Processing Record 32 of Set 4 | puerto escondido
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | severo-kurilsk
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | thompson
# Processing Record 38 of Set 4 | terrasini
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | lerwick
# Processing Record 41 of Set 4 | taoudenni
# Processing Record 42 of Set 4 | adre
# Processing Record 43 of Set 4 | polovinnoye
# Processing Record 44 of Set 4 | nishihara
# Processing Record 45 of Set 4 | witu
# Processing Record 46 of Set 4 | longyearbyen
# Processing Record 47 of Set 4 | gorontalo
# Processing Record 48 of Set 4 | matir
# City not found. Skipping...
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 4 | gouloure
# Processing Record 1 of Set 5 | san jeronimo
# Processing Record 2 of Set 5 | dauriya
# Processing Record 3 of Set 5 | arman
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | iacobeni
# Processing Record 6 of Set 5 | tuktoyaktuk
# Processing Record 7 of Set 5 | viedma
# Processing Record 8 of Set 5 | garchitorena
# Processing Record 9 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 5 | liaozhong
# Processing Record 11 of Set 5 | luanda
# Processing Record 12 of Set 5 | hami
# Processing Record 13 of Set 5 | port macquarie
# Processing Record 14 of Set 5 | rzeszow
# Processing Record 15 of Set 5 | karratha
# Processing Record 16 of Set 5 | naryan-mar
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | nuuk
# Processing Record 19 of Set 5 | macaubas
# Processing Record 20 of Set 5 | touros
# Processing Record 21 of Set 5 | katsuura
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | rabo de peixe
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | edd
# Processing Record 26 of Set 5 | balabac
# Processing Record 27 of Set 5 | hilo
# Processing Record 28 of Set 5 | segovia
# Processing Record 29 of Set 5 | roald
# Processing Record 30 of Set 5 | williamsburg
# Processing Record 31 of Set 5 | nago
# Processing Record 32 of Set 5 | ngunguru
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | aakirkeby
# City not found. Skipping...
# Processing Record 35 of Set 5 | pacific grove
# Processing Record 36 of Set 5 | kalianget
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | bintulu
# Processing Record 39 of Set 5 | lewiston
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | avera
# Processing Record 42 of Set 5 | saint anthony
# Processing Record 43 of Set 5 | oranjemund
# Processing Record 44 of Set 5 | camocim
# Processing Record 45 of Set 5 | hovd
# Processing Record 46 of Set 5 | leshukonskoye
# Processing Record 47 of Set 5 | nakamura
# Processing Record 48 of Set 5 | dingle
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | cukai
# Processing Record 1 of Set 6 | coos bay
# Processing Record 2 of Set 6 | zhaotong
# Processing Record 3 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 6 | eureka
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | huarmey
# Processing Record 7 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 6 | zeya
# Processing Record 9 of Set 6 | bluff
# Processing Record 10 of Set 6 | erenhot
# Processing Record 11 of Set 6 | kavaratti
# Processing Record 12 of Set 6 | bodden town
# Processing Record 13 of Set 6 | miramar
# Processing Record 14 of Set 6 | vagur
# Processing Record 15 of Set 6 | sitka
# Processing Record 16 of Set 6 | san cristobal
# Processing Record 17 of Set 6 | kysyl-syr
# Processing Record 18 of Set 6 | kintampo
# Processing Record 19 of Set 6 | una
# Processing Record 20 of Set 6 | black river
# Processing Record 21 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 6 | college
# Processing Record 23 of Set 6 | mvomero
# Processing Record 24 of Set 6 | tchaourou
# Processing Record 25 of Set 6 | ilulissat
# Processing Record 26 of Set 6 | martapura
# Processing Record 27 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 6 | kutum
# Processing Record 29 of Set 6 | chapais
# Processing Record 30 of Set 6 | boyolangu
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | dikson
# Processing Record 33 of Set 6 | talawdi
# City not found. Skipping...
# Processing Record 34 of Set 6 | poronaysk
# Processing Record 35 of Set 6 | kabalo
# Processing Record 36 of Set 6 | dryden
# Processing Record 37 of Set 6 | los llanos de aridane
# Processing Record 38 of Set 6 | bereda
# Processing Record 39 of Set 6 | hukuntsi
# Processing Record 40 of Set 6 | jumla
# Processing Record 41 of Set 6 | goure
# Processing Record 42 of Set 6 | lengshuitan
# Processing Record 43 of Set 6 | kaitangata
# Processing Record 44 of Set 6 | katobu
# Processing Record 45 of Set 6 | mar del plata
# Processing Record 46 of Set 6 | llallagua
# Processing Record 47 of Set 6 | wichita falls
# Processing Record 48 of Set 6 | rio claro
# Processing Record 49 of Set 6 | teodoro sampaio
# Processing Record 50 of Set 6 | harnosand
# Processing Record 1 of Set 7 | sampit
# Processing Record 2 of Set 7 | picayune
# Processing Record 3 of Set 7 | boali
# Processing Record 4 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 7 | maniitsoq
# Processing Record 6 of Set 7 | ostrovnoy
# Processing Record 7 of Set 7 | winnemucca
# Processing Record 8 of Set 7 | lima
# Processing Record 9 of Set 7 | cockburn town
# Processing Record 10 of Set 7 | guasave
# Processing Record 11 of Set 7 | kulhudhuffushi
# Processing Record 12 of Set 7 | kamaishi
# Processing Record 13 of Set 7 | comonfort
# Processing Record 14 of Set 7 | panzhihua
# Processing Record 15 of Set 7 | peterongan
# Processing Record 16 of Set 7 | iralaya
# Processing Record 17 of Set 7 | koungou
# Processing Record 18 of Set 7 | san pedro
# Processing Record 19 of Set 7 | havoysund
# Processing Record 20 of Set 7 | necochea
# Processing Record 21 of Set 7 | aykhal
# Processing Record 22 of Set 7 | seminole
# Processing Record 23 of Set 7 | russell
# Processing Record 24 of Set 7 | berlevag
# Processing Record 25 of Set 7 | banda aceh
# Processing Record 26 of Set 7 | lasalgaon
# Processing Record 27 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 7 | lata
# Processing Record 29 of Set 7 | deputatskiy
# Processing Record 30 of Set 7 | rocha
# Processing Record 31 of Set 7 | tabuny
# Processing Record 32 of Set 7 | tahta
# Processing Record 33 of Set 7 | solwezi
# Processing Record 34 of Set 7 | shelburne
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | naples
# Processing Record 37 of Set 7 | bardiyah
# Processing Record 38 of Set 7 | akdepe
# Processing Record 39 of Set 7 | bartow
# Processing Record 40 of Set 7 | naze
# Processing Record 41 of Set 7 | huntingdon
# Processing Record 42 of Set 7 | paamiut
# Processing Record 43 of Set 7 | shingu
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | palmer
# Processing Record 46 of Set 7 | okha
# Processing Record 47 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 7 | bolshaya dzhalga
# Processing Record 49 of Set 7 | les cayes
# Processing Record 50 of Set 7 | pyapon
# Processing Record 1 of Set 8 | kangaatsiaq
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | fairbanks
# Processing Record 4 of Set 8 | puerto rondon
# Processing Record 5 of Set 8 | guaraniacu
# Processing Record 6 of Set 8 | imbituba
# Processing Record 7 of Set 8 | nurota
# Processing Record 8 of Set 8 | yabelo
# Processing Record 9 of Set 8 | tecolutla
# Processing Record 10 of Set 8 | fortuna
# Processing Record 11 of Set 8 | kununurra
# Processing Record 12 of Set 8 | vernon
# Processing Record 13 of Set 8 | kesan
# Processing Record 14 of Set 8 | lomza
# Processing Record 15 of Set 8 | ketchikan
# Processing Record 16 of Set 8 | richards bay
# Processing Record 17 of Set 8 | pangody
# Processing Record 18 of Set 8 | guisa
# Processing Record 19 of Set 8 | sola
# Processing Record 20 of Set 8 | jaicos
# Processing Record 21 of Set 8 | winton
# Processing Record 22 of Set 8 | chor
# Processing Record 23 of Set 8 | ekhabi
# Processing Record 24 of Set 8 | muyinga
# Processing Record 25 of Set 8 | skibbereen
# Processing Record 26 of Set 8 | villa rica
# Processing Record 27 of Set 8 | bilma
# Processing Record 28 of Set 8 | kerrville
# Processing Record 29 of Set 8 | port lincoln
# Processing Record 30 of Set 8 | meadow lake
# Processing Record 31 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 8 | sao felix do xingu
# Processing Record 33 of Set 8 | encruzilhada
# Processing Record 34 of Set 8 | plettenberg bay
# Processing Record 35 of Set 8 | chimore
# Processing Record 36 of Set 8 | ushtobe
# Processing Record 37 of Set 8 | tekkali
# Processing Record 38 of Set 8 | tilichiki
# Processing Record 39 of Set 8 | poum
# Processing Record 40 of Set 8 | lusambo
# Processing Record 41 of Set 8 | klyazma
# City not found. Skipping...
# Processing Record 42 of Set 8 | roma
# Processing Record 43 of Set 8 | sosnogorsk
# Processing Record 44 of Set 8 | hambantota
# Processing Record 45 of Set 8 | westport
# Processing Record 46 of Set 8 | bagdarin
# Processing Record 47 of Set 8 | sobolevo
# Processing Record 48 of Set 8 | sakaiminato
# Processing Record 49 of Set 8 | motygino
# Processing Record 50 of Set 8 | qaqortoq
# Processing Record 1 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 2 of Set 9 | arkadak
# Processing Record 3 of Set 9 | yumen
# Processing Record 4 of Set 9 | jalu
# Processing Record 5 of Set 9 | maragogi
# Processing Record 6 of Set 9 | colares
# Processing Record 7 of Set 9 | shenzhen
# Processing Record 8 of Set 9 | arroyo
# Processing Record 9 of Set 9 | mahibadhoo
# Processing Record 10 of Set 9 | kristiansund
# Processing Record 11 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 9 | idlib
# Processing Record 13 of Set 9 | tromso
# Processing Record 14 of Set 9 | hun
# Processing Record 15 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 16 of Set 9 | coihaique
# Processing Record 17 of Set 9 | camopi
# Processing Record 18 of Set 9 | belmonte
# Processing Record 19 of Set 9 | takoradi
# Processing Record 20 of Set 9 | gamba
# Processing Record 21 of Set 9 | boende
# Processing Record 22 of Set 9 | sangmelima
# Processing Record 23 of Set 9 | talavera de la reina
# Processing Record 24 of Set 9 | ayia galini
# Processing Record 25 of Set 9 | chapleau
# Processing Record 26 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 27 of Set 9 | sharya
# Processing Record 28 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 9 | blythe
# Processing Record 30 of Set 9 | beeville
# Processing Record 31 of Set 9 | khonsa
# Processing Record 32 of Set 9 | savannah bight
# Processing Record 33 of Set 9 | sechura
# Processing Record 34 of Set 9 | grindavik
# Processing Record 35 of Set 9 | baykit
# Processing Record 36 of Set 9 | kapoeta
# Processing Record 37 of Set 9 | sao filipe
# Processing Record 38 of Set 9 | luz
# Processing Record 39 of Set 9 | rio grande
# Processing Record 40 of Set 9 | nombre de dios
# Processing Record 41 of Set 9 | buala
# Processing Record 42 of Set 9 | darhan
# Processing Record 43 of Set 9 | shimoda
# Processing Record 44 of Set 9 | surgut
# Processing Record 45 of Set 9 | kainantu
# Processing Record 46 of Set 9 | vejle
# Processing Record 47 of Set 9 | san patricio
# Processing Record 48 of Set 9 | kasongo-lunda
# Processing Record 49 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 50 of Set 9 | elko
# Processing Record 1 of Set 10 | rioja
# Processing Record 2 of Set 10 | andra
# Processing Record 3 of Set 10 | obidos
# Processing Record 4 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 10 | yankton
# Processing Record 6 of Set 10 | palora
# Processing Record 7 of Set 10 | porto novo
# Processing Record 8 of Set 10 | sao sebastiao
# Processing Record 9 of Set 10 | tezu
# Processing Record 10 of Set 10 | daru
# Processing Record 11 of Set 10 | muzhi
# Processing Record 12 of Set 10 | harper
# Processing Record 13 of Set 10 | soto la marina
# Processing Record 14 of Set 10 | saint-philippe
# Processing Record 15 of Set 10 | vesoul
# Processing Record 16 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 17 of Set 10 | rawson
# Processing Record 18 of Set 10 | birakan
# Processing Record 19 of Set 10 | upata
# Processing Record 20 of Set 10 | quatre cocos
# Processing Record 21 of Set 10 | liseleje
# Processing Record 22 of Set 10 | cesis
# Processing Record 23 of Set 10 | nizhniy tsasuchey
# Processing Record 24 of Set 10 | dongning
# Processing Record 25 of Set 10 | khani
# Processing Record 26 of Set 10 | tonantins
# Processing Record 27 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 10 | sambava
# Processing Record 29 of Set 10 | makakilo city
# Processing Record 30 of Set 10 | setermoen
# Processing Record 31 of Set 10 | merauke
# Processing Record 32 of Set 10 | kavieng
# Processing Record 33 of Set 10 | aksu
# Processing Record 34 of Set 10 | seoul
# Processing Record 35 of Set 10 | bakhtiyarpur
# Processing Record 36 of Set 10 | swan hill
# Processing Record 37 of Set 10 | bauchi
# Processing Record 38 of Set 10 | pochutla
# Processing Record 39 of Set 10 | kabo
# Processing Record 40 of Set 10 | lorengau
# Processing Record 41 of Set 10 | nynashamn
# Processing Record 42 of Set 10 | zyryanka
# Processing Record 43 of Set 10 | trairi
# Processing Record 44 of Set 10 | sortova
# Processing Record 45 of Set 10 | malangwa
# Processing Record 46 of Set 10 | san policarpo
# Processing Record 47 of Set 10 | bollnas
# Processing Record 48 of Set 10 | amahai
# Processing Record 49 of Set 10 | kismayo
# Processing Record 50 of Set 10 | arauca
# Processing Record 1 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 11 | san vicente
# Processing Record 3 of Set 11 | lakatoro
# Processing Record 4 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 11 | bonthe
# Processing Record 6 of Set 11 | dunda
# Processing Record 7 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 11 | kanye
# Processing Record 9 of Set 11 | dongying
# Processing Record 10 of Set 11 | boissevain
# Processing Record 11 of Set 11 | sedhiou
# Processing Record 12 of Set 11 | vanimo
# Processing Record 13 of Set 11 | batemans bay
# Processing Record 14 of Set 11 | mrakovo
# Processing Record 15 of Set 11 | pangnirtung
# Processing Record 16 of Set 11 | saint george
# Processing Record 17 of Set 11 | pacifica
# Processing Record 18 of Set 11 | nara
# Processing Record 19 of Set 11 | ginda
# Processing Record 20 of Set 11 | santa cruz
# Processing Record 21 of Set 11 | monrovia
# Processing Record 22 of Set 11 | launceston
# Processing Record 23 of Set 11 | znamensk
# Processing Record 24 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 25 of Set 11 | kirakira
# Processing Record 26 of Set 11 | tazovskiy
# Processing Record 27 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 11 | nan
# Processing Record 29 of Set 11 | seymchan
# Processing Record 30 of Set 11 | sarandi
# Processing Record 31 of Set 11 | goderich
# Processing Record 32 of Set 11 | nioro
# Processing Record 33 of Set 11 | kharhial
# Processing Record 34 of Set 11 | claresholm
# Processing Record 35 of Set 11 | arlit
# Processing Record 36 of Set 11 | lincoln
# Processing Record 37 of Set 11 | saint-fabien
# City not found. Skipping...
# Processing Record 38 of Set 11 | klaksvik
# Processing Record 39 of Set 11 | sungaipenuh
# Processing Record 40 of Set 11 | rio gallegos
# Processing Record 41 of Set 11 | namatanai
# Processing Record 42 of Set 11 | azul
# Processing Record 43 of Set 11 | batagay-alyta
# Processing Record 44 of Set 11 | namie
# Processing Record 45 of Set 11 | sao gabriel da cachoeira
# Processing Record 46 of Set 11 | malanje
# Processing Record 47 of Set 11 | athabasca
# Processing Record 48 of Set 11 | suba
# Processing Record 49 of Set 11 | anchorage
# Processing Record 50 of Set 11 | anadyr
# Processing Record 1 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 12 | kyaukse
# Processing Record 3 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 12 | davila
# Processing Record 5 of Set 12 | ayan
# Processing Record 6 of Set 12 | bonavista
# Processing Record 7 of Set 12 | yakeshi
# Processing Record 8 of Set 12 | halifax
# Processing Record 9 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 10 of Set 12 | banjarmasin
# Processing Record 11 of Set 12 | byron bay
# Processing Record 12 of Set 12 | bani
# Processing Record 13 of Set 12 | bubaque
# Processing Record 14 of Set 12 | alto araguaia
# Processing Record 15 of Set 12 | gravdal
# Processing Record 16 of Set 12 | ambilobe
# Processing Record 17 of Set 12 | santa rosa
# Processing Record 18 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 12 | kirkland lake
# Processing Record 20 of Set 12 | pisco
# Processing Record 21 of Set 12 | gualeguay
# Processing Record 22 of Set 12 | nieuwpoort
# Processing Record 23 of Set 12 | constitucion
# Processing Record 24 of Set 12 | labuhan
# Processing Record 25 of Set 12 | cascais
# Processing Record 26 of Set 12 | menongue
# Processing Record 27 of Set 12 | liverpool
# Processing Record 28 of Set 12 | port hardy
# Processing Record 29 of Set 12 | port hedland
# Processing Record 30 of Set 12 | baglung
# Processing Record 31 of Set 12 | sibu
# Processing Record 32 of Set 12 | hailar
# Processing Record 33 of Set 12 | aliwal north
# Processing Record 34 of Set 12 | colac
# Processing Record 35 of Set 12 | tambacounda
# Processing Record 36 of Set 12 | mayor pablo lagerenza
# Processing Record 37 of Set 12 | nagarote
# Processing Record 38 of Set 12 | nha trang
# Processing Record 39 of Set 12 | emerald
# Processing Record 40 of Set 12 | toyooka
# Processing Record 41 of Set 12 | otjimbingwe
# Processing Record 42 of Set 12 | along
# Processing Record 43 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 12 | mizdah
# Processing Record 45 of Set 12 | njombe
# Processing Record 46 of Set 12 | charters towers
# Processing Record 47 of Set 12 | la macarena
# Processing Record 48 of Set 12 | qax
# Processing Record 49 of Set 12 | yaan
# Processing Record 50 of Set 12 | mazagao
# Processing Record 1 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 13 | haines junction
# Processing Record 3 of Set 13 | saint-louis
# Processing Record 4 of Set 13 | paita
# Processing Record 5 of Set 13 | opuwo
# Processing Record 6 of Set 13 | christchurch
# Processing Record 7 of Set 13 | kampot
# Processing Record 8 of Set 13 | banamba
# Processing Record 9 of Set 13 | preobrazheniye
# Processing Record 10 of Set 13 | husavik
# Processing Record 11 of Set 13 | tocopilla
# Processing Record 12 of Set 13 | gore
# Processing Record 13 of Set 13 | nortelandia
# Processing Record 14 of Set 13 | kandalaksha
# Processing Record 15 of Set 13 | meulaboh
# Processing Record 16 of Set 13 | erzin
# Processing Record 17 of Set 13 | namtsy
# Processing Record 18 of Set 13 | san lawrenz
# Processing Record 19 of Set 13 | jining
# Processing Record 20 of Set 13 | san juan
# Processing Record 21 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 13 | dongsheng
# Processing Record 23 of Set 13 | ugoofaaru
# Processing Record 24 of Set 13 | kudahuvadhoo
# Processing Record 25 of Set 13 | krasnoarmeysk
# Processing Record 26 of Set 13 | kaniama
# Processing Record 27 of Set 13 | camacha
# Processing Record 28 of Set 13 | araouane
# Processing Record 29 of Set 13 | ende
# Processing Record 30 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 13 | caravelas
# Processing Record 32 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 13 | uvat
# Processing Record 34 of Set 13 | vanavara
# Processing Record 35 of Set 13 | asfi
# Processing Record 36 of Set 13 | omsukchan
# Processing Record 37 of Set 13 | sioux lookout
# Processing Record 38 of Set 13 | prince rupert
# Processing Record 39 of Set 13 | celestun
# Processing Record 40 of Set 13 | inhambane
# Processing Record 41 of Set 13 | tiznit
# Processing Record 42 of Set 13 | loubomo
# Processing Record 43 of Set 13 | beringovskiy
# Processing Record 44 of Set 13 | northampton
# Processing Record 45 of Set 13 | areia branca
# Processing Record 46 of Set 13 | marsa matruh
# Processing Record 47 of Set 13 | umm lajj
# Processing Record 48 of Set 13 | kidal
# Processing Record 49 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 50 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 14 | valleyview
# Processing Record 2 of Set 14 | bar-le-duc
# Processing Record 3 of Set 14 | marawi
# Processing Record 4 of Set 14 | aktau
# Processing Record 5 of Set 14 | burica
# City not found. Skipping...
# Processing Record 6 of Set 14 | posse
# Processing Record 7 of Set 14 | zhanaozen
# Processing Record 8 of Set 14 | chimoio
# Processing Record 9 of Set 14 | tabuk
# Processing Record 10 of Set 14 | buchanan
# Processing Record 11 of Set 14 | nyurba
# Processing Record 12 of Set 14 | axim
# Processing Record 13 of Set 14 | vrangel
# Processing Record 14 of Set 14 | foshan
# Processing Record 15 of Set 14 | mercedes
# Processing Record 16 of Set 14 | kijang
# Processing Record 17 of Set 14 | cavalcante
# Processing Record 18 of Set 14 | biltine
# Processing Record 19 of Set 14 | roebourne
# Processing Record 20 of Set 14 | varnavino
# Processing Record 21 of Set 14 | endicott
# Processing Record 22 of Set 14 | chivay
# Processing Record 23 of Set 14 | soe
# Processing Record 24 of Set 14 | kitimat
# Processing Record 25 of Set 14 | moose factory
# Processing Record 26 of Set 14 | bulgan
# Processing Record 27 of Set 14 | zhuzhou
# Processing Record 28 of Set 14 | gumdag
# Processing Record 29 of Set 14 | nacala
# Processing Record 30 of Set 14 | faya
# Processing Record 31 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 32 of Set 14 | lamu
# Processing Record 33 of Set 14 | katherine
# Processing Record 34 of Set 14 | kurumkan
# Processing Record 35 of Set 14 | vao
# Processing Record 36 of Set 14 | chara
# Processing Record 37 of Set 14 | garowe
# Processing Record 38 of Set 14 | el sauzal
# Processing Record 39 of Set 14 | quimper
# Processing Record 40 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 14 | esmeraldas
# Processing Record 42 of Set 14 | sa kaeo
# Processing Record 43 of Set 14 | pangai
# Processing Record 44 of Set 14 | forbes
# Processing Record 45 of Set 14 | carutapera
# Processing Record 46 of Set 14 | hay river
# Processing Record 47 of Set 14 | egvekinot
# Processing Record 48 of Set 14 | grimmen
# Processing Record 49 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 14 | lezajsk
# Processing Record 1 of Set 15 | mirnyy
# Processing Record 2 of Set 15 | pitimbu
# Processing Record 3 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 4 of Set 15 | porangatu
# Processing Record 5 of Set 15 | cimitarra
# Processing Record 6 of Set 15 | frontera
# Processing Record 7 of Set 15 | champerico
# Processing Record 8 of Set 15 | balurghat
# Processing Record 9 of Set 15 | poso
# Processing Record 10 of Set 15 | galle
# Processing Record 11 of Set 15 | billings
# Processing Record 12 of Set 15 | filingue
# Processing Record 13 of Set 15 | mollendo
# Processing Record 14 of Set 15 | noumea
# Processing Record 15 of Set 15 | luena
# Processing Record 16 of Set 15 | aksarka
# Processing Record 17 of Set 15 | quelimane
# Processing Record 18 of Set 15 | abonnema
# Processing Record 19 of Set 15 | nemuro
# Processing Record 20 of Set 15 | gat
# Processing Record 21 of Set 15 | inverell
# Processing Record 22 of Set 15 | parsabad
# Processing Record 23 of Set 15 | ahipara
# Processing Record 24 of Set 15 | yalvac
# Processing Record 25 of Set 15 | san carlos de bariloche
# Processing Record 26 of Set 15 | inyonga
# Processing Record 27 of Set 15 | bud
# Processing Record 28 of Set 15 | hrubieszow
# Processing Record 29 of Set 15 | havelock
# Processing Record 30 of Set 15 | kichha
# Processing Record 31 of Set 15 | staryy nadym
# Processing Record 32 of Set 15 | uyuni
# Processing Record 33 of Set 15 | baft
# Processing Record 34 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 35 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 36 of Set 15 | sfantu gheorghe
# Processing Record 37 of Set 15 | zhigansk
# Processing Record 38 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 39 of Set 15 | kahului
# Processing Record 40 of Set 15 | jijiga
# Processing Record 41 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 15 | tomatlan
# Processing Record 43 of Set 15 | nang rong
# Processing Record 44 of Set 15 | matagami
# Processing Record 45 of Set 15 | boa vista
# Processing Record 46 of Set 15 | bela vista
# Processing Record 47 of Set 15 | sistranda
# Processing Record 48 of Set 15 | santiago del estero
# Processing Record 49 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 50 of Set 15 | new ulm
# Processing Record 1 of Set 16 | contai
# Processing Record 2 of Set 16 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 16 | saint-paul
# Processing Record 4 of Set 16 | okoneshnikovo
# Processing Record 5 of Set 16 | tessalit
# Processing Record 6 of Set 16 | hinundayan
# Processing Record 7 of Set 16 | cedar city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     43.95        93         100
# 1     Saskylakh      RU  71.9167  114.0833    -55.64       100          64
# 2        Hobart      AU -42.8794  147.3294     66.06        84          21
# 3     Carnarvon      AU -24.8667  113.6333     74.53        73           0
# 4        Yulara      AU -25.2406  130.9889     83.23        33           2
# 5     Cape Town      ZA -33.9258   18.4232     76.10        57          20
# 6     Jamestown      US  42.0970  -79.2353     28.02        75         100
# 7  Puerto Ayora      EC  -0.7393  -90.3518     77.56        88          84
# 8  Punta Arenas      CL -53.1500  -70.9167     59.02        54          40
# 9     Busselton      AU -33.6500  115.3333     58.39        69           1
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1        3.71       broken clouds
# 2        6.91          few clouds
# 3       25.37           clear sky
# 4        6.38           clear sky
# 5       13.80          few clouds
# 6       11.50          light snow
# 7        7.00       broken clouds
# 8       29.93    scattered clouds
# 9       16.31           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     43.95        93         100
# 1     Saskylakh      RU  71.9167  114.0833    -55.64       100          64
# 2        Hobart      AU -42.8794  147.3294     66.06        84          21
# 3     Carnarvon      AU -24.8667  113.6333     74.53        73           0
# 4        Yulara      AU -25.2406  130.9889     83.23        33           2
# 5     Cape Town      ZA -33.9258   18.4232     76.10        57          20
# 6     Jamestown      US  42.0970  -79.2353     28.02        75         100
# 7  Puerto Ayora      EC  -0.7393  -90.3518     77.56        88          84
# 8  Punta Arenas      CL -53.1500  -70.9167     59.02        54          40
# 9     Busselton      AU -33.6500  115.3333     58.39        69           1
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1        3.71       broken clouds
# 2        6.91          few clouds
# 3       25.37           clear sky
# 4        6.38           clear sky
# 5       13.80          few clouds
# 6       11.50          light snow
# 7        7.00       broken clouds
# 8       29.93    scattered clouds
# 9       16.31           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE


# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
